# %% [markdown]
# # **GRIPAPR21, The Sparks Foundation**
#
# ## **Task 6: Prediction using Decision Tree Algorithm**
#
# ### Author: Naman Agarwal

# %% [markdown]
# ### **Importing necessary libraries**

# %%
# Importing libraries in Python
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import sklearn.datasets as datasets
from sklearn.metrics import confusion_matrix 
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
from sklearn import tree 
from sklearn import metrics

# %%
# Loading the iris dataset
iris = pd.read_csv('/Users/namanagarwal/Downloads/Iris (1).csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
X = df.drop('Species', axis=1)
y = pd.get_dummies(df.Species)

# %%
dummy = pd.concat((X,y), axis=1)
dummy
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Iris-setosa  \
# 0              5.1           3.5            1.4           0.2            1
# 1              4.9           3.0            1.4           0.2            1
# 2              4.7           3.2            1.3           0.2            1
# 3              4.6           3.1            1.5           0.2            1
# 4              5.0           3.6            1.4           0.2            1
# ..             ...           ...            ...           ...          ...
# 145            6.7           3.0            5.2           2.3            0
# 146            6.3           2.5            5.0           1.9            0
# 147            6.5           3.0            5.2           2.0            0
# 148            6.2           3.4            5.4           2.3            0
# 149            5.9           3.0            5.1           1.8            0
#
#      Iris-versicolor  Iris-virginica
# ...

# %%
plt.figure (figsize=(7,5), dpi= 100, facecolor='w')
sns.heatmap(dummy.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### **Visualizing Data**

# %%
iris.drop(['Id'], axis = 'columns', inplace=True)
plt.figure (figsize=(6,10), dpi= 100, facecolor='w')
sns.pairplot(iris,  hue = "Species")

# %%
#forming train test dataset
train,test=train_test_split(iris,test_size=0.3)
print(train.shape)
print(test.shape)
# Out:
# (105, 5)
# (45, 5)

# %%
train_X = train[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]# taking the training data features
train_y=train.Species# output of our training data
test_X= test[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']] # taking test data features
test_y =test.Species   #output value of test data

# %% [markdown]
# ### Now let us define the Decision Tree Algorithm

# %%
#Defining decision tree algorithm
dtree = DecisionTreeClassifier(max_depth = 3,random_state = 1)
model_all_params = DecisionTreeClassifier().fit(train_X,train_y)

print("The Decision Tree Classifier created")
# Out:
# The Decision Tree Classifier created

# %%
#prediction
prediction = model_all_params.predict(test_X)

# %%
#taking an example to seee prediction
X=[[5.3,2.5,1.3,0.3]]
pre=model_all_params.predict(X)
print(pre)
# Out:
# ['Iris-setosa']

# %%
#Accuracy 
print('The accuracy of decision tree is',"{:.3f}".format(metrics.accuracy_score(prediction,test_y)))
# Out:
# The accuracy of decision tree is 0.933

# %% [markdown]
# **Hence, we can conclude that model is 95.6% accurate.**

# %%
Input=iris.loc[:,['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']] 
target=iris.loc[:,'Species']

# %% [markdown]
# ### **Tree Model for the given Data**

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn import tree 
plt.figure(figsize = (50,30))
newModel= DecisionTreeClassifier().fit(Input,target) 
tree = tree.plot_tree(newModel,feature_names=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],
                      class_names=['Iris-setosa','Iris-versicolor', 'Iris-virginica'], filled =True)

# %%
X_train, X_test, y_train, y_test = train_test_split( 
    Input, target, test_size = 0.3, random_state = 100) 

print(X_train.shape ,X_test.shape ,y_train.shape ,y_test.shape)
# Out:
# (105, 4) (45, 4) (105,) (45,)

# %% [markdown]
# #### **Tree model Initialization for the purpose of testing Species based on the given data**

# %%
treeModel=DecisionTreeClassifier() 
treeModel.fit(X_train,y_train) 
predictedOutput=treeModel.predict(X_test)

# %% [markdown]
# #### **Comparing the Actual and Predicted Species**

# %%
comparisonTable=pd.DataFrame({'Actual Species': y_test,'Predicted Species':predictedOutput}) 
comparisonTable
# Out:
#       Actual Species Predicted Species
# 128   Iris-virginica    Iris-virginica
# 11       Iris-setosa       Iris-setosa
# 118   Iris-virginica    Iris-virginica
# 15       Iris-setosa       Iris-setosa
# 123   Iris-virginica    Iris-virginica
# 135   Iris-virginica    Iris-virginica
# 32       Iris-setosa       Iris-setosa
# 1        Iris-setosa       Iris-setosa
# 116   Iris-virginica    Iris-virginica
# 45       Iris-setosa       Iris-setosa
# 40       Iris-setosa       Iris-setosa
# 115   Iris-virginica    Iris-virginica
# 26       Iris-setosa       Iris-setosa
# 28       Iris-setosa       Iris-setosa
# 145   Iris-virginica    Iris-virginica
# 97   Iris-versicolor   Iris-versicolor
# 62   Iris-versicolor   Iris-versicolor
# 77   Iris-versicolor    Iris-virginica
# 122   Iris-virginica    Iris-virginica
# 112   Iris-virginica    Iris-virginica
# 125   Iris-virginica    Iris-virginica
# 31       Iris-setosa       Iris-setosa
# 146   Iris-virginica    Iris-virginica
# ...

# %% [markdown]
# ### **Tree Model for the testing data where the species data are collected from the  given dataset**

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn import tree 
TestModel= DecisionTreeClassifier().fit(X_test,y_test) 
plt.figure(figsize = (35,15))
tree1 = tree.plot_tree(TestModel,feature_names=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],
                      class_names=['Iris-setosa','Iris-versicolor', 'Iris-virginica'], filled =True)

# %% [markdown]
# ### **Tree model for testing data where the species data is predicted**

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn import tree 
TestModel= DecisionTreeClassifier().fit(X_test, predictedOutput) 
plt.figure(figsize = (10,10))
tree2 = tree.plot_tree(TestModel,feature_names=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],
                      class_names=['Iris-setosa','Iris-versicolor', 'Iris-virginica'], filled =True)

# %% [markdown]
# #### **Accuracy Calculation**

# %%
accuracy_score(y_test, predictedOutput)
# Out:
# 0.9555555555555556

# %% [markdown]
# ### _**Thank you for taking the time to watch this video!**_
